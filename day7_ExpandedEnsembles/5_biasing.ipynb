# %% [markdown]
# Monte Carlo Simulation to Computed Adsorption in a Metal-Organic Framework
#
# # Exercise 3: Result of the comparison

# %%
import numpy as np
import matplotlib.pyplot as plt

fugacity_conventional = [1e0, 1e1, 1e2, 1e3, 1e4, 1e5, 1e6, 1e7, 1e8, 1e9, 1e10]
loading_conventional = [
    1.230550e-01,
    1.158265e00,
    1.002618e01,
    3.424474e01,
    1.819090e02,
    2.011196e02,
    2.140322e02,
    2.196341e02,
    2.247062e02,
    2.258271e02,
    2.255468e02,
]
loading_error_conventional = [
    7.904761e-03,
    7.209103e-02,
    4.833829e-01,
    9.110376e-01,
    2.468011e00,
    1.482671e00,
    1.385070e00,
    7.646734e-01,
    4.057684e-01,
    4.800259e-01,
    7.901519e-01,
]
insertion_acceptance_conventional = [
    0.010035,
    0.021153,
    0.024605,
    0.042101,
    0.000289,
    0.000016,
    0.000001,
    0.000001,
    0.0,
    0.0,
    0.0,
]

fugacity_cbmc = [1e0, 1e1, 1e2, 1e3, 1e4, 1e5, 1e6, 1e7, 1e8, 1e9, 1e10]
loading_cbmc = [
    1.203350e-01,
    1.171200e00,
    9.892695e00,
    3.382317e01,
    1.819633e02,
    2.008284e02,
    2.141273e02,
    2.224027e02,
    2.340593e02,
    2.411060e02,
    2.418281e02,
]
loading_error_cbmc = [
    5.586704e-03,
    2.705853e-02,
    3.704803e-01,
    5.649468e-01,
    7.181383e-01,
    1.416257e00,
    1.662096e00,
    1.174529e00,
    3.162146e00,
    1.716969e-01,
    1.122799e00,
]
insertion_acceptance_cbmc = [
    0.061360,
    0.116572,
    0.088380,
    0.119337,
    0.008373,
    0.000671,
    0.000082,
    0.000016,
    0.000003,
    0.000001,
    0.0000001,
]

fugacity_cfcmc = [1e0, 1e1, 1e2, 1e3, 1e4, 1e5, 1e6, 1e7, 1e8, 1e9, 1e10]
loading_cfcmc = [
    1.140899e-01,
    1.066633e00,
    9.267135e00,
    3.331124e01,
    1.798314e02,
    2.016795e02,
    2.097900e02,
    2.170443e02,
    2.266320e02,
    2.332644e02,
    2.408945e02,
]
loading_error_cfcmc = [
    2.009240e-02,
    1.280510e-01,
    3.556339e-01,
    8.536027e-01,
    1.262065e00,
    2.797692e00,
    2.347441e00,
    1.291437e00,
    1.045885e00,
    1.045770e00,
    3.333665e00,
]
insertion_acceptance_cfcmc = [
    0.041901,
    0.174040,
    0.277601,
    0.314927,
    0.305149,
    0.321218,
    0.363839,
    0.343145,
    0.341152,
    0.361746,
    0.343816,
]

fugacity_cb_cfcmc = [1e0, 1e1, 1e2, 1e3, 1e4, 1e5, 1e6, 1e7, 1e8, 1e9, 1e10]
loading_cb_cfcmc = [
    1.132931e-01,
    1.129038e00,
    9.399145e00,
    3.375431e01,
    1.806442e02,
    1.987143e02,
    2.128091e02,
    2.220653e02,
    2.315629e02,
    2.397886e02,
    2.427434e02,
]
loading_error_cb_cfcmc = [
    3.565945e-03,
    5.765424e-02,
    3.524083e-01,
    8.988905e-01,
    2.262383e00,
    1.038149e00,
    2.810204e00,
    1.179683e00,
    1.808077e00,
    1.070252e00,
    2.530985e00,
]
insertion_acceptance_cb_cfcmc = [
    0.077503,
    0.261143,
    0.373890,
    0.480041,
    0.365408,
    0.410895,
    0.398399,
    0.415779,
    0.396672,
    0.401736,
    0.430004,
]

fig, ax1 = plt.subplots()
ax1.set_title("CB/CFCMC vs CFCMC vs CBMC vs Conventional insertion scheme 200K", fontsize=10)
ax1.set_xlabel("fugacity f / Pa", fontsize=20)
ax1.set_ylabel("Absolute loading / molecules.cell$^{-1}$", fontsize=16)
ax1.set_xscale("log")
ax1.errorbar(
    fugacity_conventional,
    loading_conventional,
    yerr=loading_error_conventional,
    color="purple",
    label="Loading conv.",
    marker="s",
)
ax1.errorbar(fugacity_cbmc, loading_cbmc, yerr=loading_error_cbmc, color="red", label="Loading cbmc", marker="o")
ax1.errorbar(fugacity_cfcmc, loading_cfcmc, yerr=loading_error_cfcmc, color="black", label="Loading cfcmc", marker="o")
ax1.errorbar(
    fugacity_cb_cfcmc,
    loading_cb_cfcmc,
    yerr=loading_error_cb_cfcmc,
    color="lightblue",
    label="Loading cb.cfcmc",
    marker="+",
)
ax1.legend(loc="upper right")
plt.ylim([0, 350])
ax2 = ax1.twinx()
ax2.set_xlabel("fugacity f / Pa", fontsize=20)
ax2.set_ylabel(ylabel="Insertion Acceptance / -", fontsize=16)
ax2.errorbar(
    fugacity_conventional, insertion_acceptance_conventional, color="green", label="acceptance conv.", marker="+"
)
ax2.errorbar(fugacity_cbmc, insertion_acceptance_cbmc, color="blue", label="acceptance cbmc", marker="*")
ax2.errorbar(fugacity_cfcmc, insertion_acceptance_cfcmc, color="orange", label="acceptance cfcmc", marker="^")
ax2.errorbar(fugacity_cb_cfcmc, insertion_acceptance_cb_cfcmc, color="cyan", label="acceptance cb/cfcmc", marker="^")
ax2.legend(loc="upper left")
# ax2.set_yscale("log")
plt.ylim([0, 1.0])

# %% [markdown]
# # Exercise 3c: Biasing

# %%
import numpy as np
import matplotlib.pyplot as plt

lambdas = [
    0.000000,
    0.025000,
    0.050000,
    0.075000,
    0.100000,
    0.125000,
    0.150000,
    0.175000,
    0.200000,
    0.225000,
    0.250000,
    0.275000,
    0.300000,
    0.325000,
    0.350000,
    0.375000,
    0.400000,
    0.425000,
    0.450000,
    0.475000,
    0.500000,
    0.525000,
    0.550000,
    0.575000,
    0.600000,
    0.625000,
    0.650000,
    0.675000,
    0.700000,
    0.725000,
    0.750000,
    0.775000,
    0.800000,
    0.825000,
    0.850000,
    0.875000,
    0.900000,
    0.925000,
    0.950000,
    0.975000,
    1.000000,
]
bias_1e2 = [
    5.626411288871594,
    5.608271309340324,
    5.661246646835195,
    5.595819591545421,
    5.662998607552595,
    5.615793177257814,
    5.418643652131948,
    5.220228721241398,
    4.763416840249164,
    4.406307399534228,
    3.968630399212458,
    3.3172019628468377,
    2.7998553360157246,
    2.160937590750592,
    1.6780995826585183,
    1.3755778177635705,
    1.0307419686472201,
    0.8256971748076865,
    0.6054358766193104,
    0.5818684109721062,
    0.5776127852926152,
    0.5570712384050864,
    0.5081460031326515,
    0.5498008302622566,
    0.5276700636809721,
    0.5604707344984377,
    0.5398466068824348,
    0.4982864053163212,
    0.40151273812853105,
    0.4623161200831305,
    0.3755365650175122,
    0.29659944609917943,
    0.3277503202878904,
    0.21593535271173891,
    0.13848700599166364,
    0.1382609897502789,
    0.143995724925162,
    0.10468200769562941,
    -0.007181470956822977,
    0.01335888969839516,
    0.0,
]
bias_1e4 = [
    5.848389197953708,
    5.837024268081819,
    5.889866662009041,
    5.809588211491047,
    5.858004315838286,
    5.830153674286578,
    1.4015007336756753,
    1.062874853366793,
    0.779504803571399,
    0.4968867966990729,
    0.3068227705416575,
    0.15942294998512807,
    0.0642906411308104,
    0.008031620986912458,
    0.0,
]

fig, ax1 = plt.subplots()
ax1.set_title("CB/CFCMC bias factors 200K", fontsize=10)
ax1.set_xlabel(r"Coupling parameter $\lambda$ / -", fontsize=20)
ax1.set_ylabel("Bias Factor / -", fontsize=20)
# ax1.set_xscale("log")
ax1.errorbar(lambdas, bias_1e2, color="purple", label="f = 1e2 Pa", marker="+")
ax1.errorbar(lambdas, bias_1e4, color="red", label="f = 1e4 Pa", marker="s")
ax1.errorbar(lambdas, bias_1e6, color="black", label="f = 1e6 Pa", marker="<")
ax1.errorbar(lambdas, bias_1e8, color="lightblue", label="f = 1e8 Pa", marker="^")
ax1.errorbar(lambdas, bias_1e10, color="orange", label="f = 1e10 Pa", marker="o")
ax1.legend(loc="upper right")
plt.xlim([0, 1.0])

# %% [markdown]
# # Exercise 3c: Histograms

# %%
import numpy as np
import matplotlib.pyplot as plt

lambdas = [
    0.000000,
    0.025000,
    0.050000,
    0.075000,
    0.100000,
    0.125000,
    0.150000,
    0.175000,
    0.200000,
    0.225000,
    0.250000,
    0.275000,
    0.300000,
    0.325000,
    0.350000,
    0.375000,
    0.400000,
    0.425000,
    0.450000,
    0.475000,
    0.500000,
    0.525000,
    0.550000,
    0.575000,
    0.600000,
    0.625000,
    0.650000,
    0.675000,
    0.700000,
    0.725000,
    0.750000,
    0.775000,
    0.800000,
    0.825000,
    0.850000,
    0.875000,
    0.900000,
    0.925000,
    0.950000,
    0.975000,
    1.000000,
]
histograms_1e2 = [
    1.01782e00,
    9.70880e-01,
    1.05719e00,
    9.97735e-01,
    1.06272e00,
    1.07236e00,
    1.01475e00,
    1.07892e00,
    9.35005e-01,
    9.86870e-01,
    1.06067e00,
    1.00942e00,
    1.05288e00,
    9.61450e-01,
    9.60015e-01,
    1.03546e00,
    1.01455e00,
    1.04448e00,
    9.63500e-01,
    1.00286e00,
    1.02439e00,
    1.00225e00,
    9.68625e-01,
    9.84000e-01,
    1.00122e00,
    1.02541e00,
    1.01967e00,
    9.86460e-01,
    9.17170e-01,
    1.00696e00,
    9.74160e-01,
    9.59195e-01,
    1.02275e00,
    9.62885e-01,
    9.59605e-01,
    9.85640e-01,
    1.05432e00,
    1.00389e00,
    9.40130e-01,
    9.60425e-01,
    9.41360e-01,
]
histograms_1e4 = [
    1.02562e00,
    1.03177e00,
    1.06744e00,
    9.72520e-01,
    1.01024e00,
    9.98555e-01,
    1.01619e00,
    1.01660e00,
    1.04673e00,
    9.55095e-01,
    1.02972e00,
    9.83795e-01,
    1.01516e00,
    1.01291e00,
    1.01865e00,
    9.78875e-01,
    9.62680e-01,
    9.63500e-01,
    1.00409e00,
    1.01455e00,
    9.53660e-01,
    9.96095e-01,
    1.00758e00,
    9.87690e-01,
    9.51200e-01,
    9.96915e-01,
    9.99785e-01,
    1.00450e00,
    9.40540e-01,
    9.55915e-01,
    9.94660e-01,
    1.01004e00,
    1.05227e00,
    1.03423e00,
    1.03054e00,
    9.99990e-01,
    1.03402e00,
    9.83590e-01,
    9.87280e-01,
    9.98555e-01,
    9.56325e-01,
]
histograms_1e6 = [
    9.31930e-01,
    9.70880e-01,
    9.47920e-01,
    9.58990e-01,
    9.47510e-01,
    9.42795e-01,
    1.00696e00,
    1.15681e00,
    1.36325e00,
    1.41122e00,
    1.24374e00,
    1.13877e00,
    1.04017e00,
    1.03546e00,
    9.94865e-01,
    9.69650e-01,
    1.00470e00,
    9.66370e-01,
    9.95685e-01,
    9.76825e-01,
    9.68215e-01,
    9.42385e-01,
    9.81540e-01,
    9.62885e-01,
    9.79900e-01,
    9.54890e-01,
    9.74160e-01,
    9.70060e-01,
    9.62065e-01,
    9.41770e-01,
    9.78670e-01,
    9.36440e-01,
    9.45460e-01,
    9.21885e-01,
    9.29675e-01,
    9.53045e-01,
    9.19630e-01,
    9.23935e-01,
    9.49150e-01,
    9.50995e-01,
    9.48740e-01,
]
histograms_1e8 = [
    1.09798e00,
    1.09019e00,
    1.09757e00,
    1.04857e00,
    1.03791e00,
    1.02807e00,
    9.09790e-01,
    7.21190e-01,
    6.38575e-01,
    7.19345e-01,
    9.60630e-01,
    1.02643e00,
    1.05780e00,
    1.03730e00,
    9.86050e-01,
    1.00778e00,
    9.71495e-01,
    9.81540e-01,
    9.86255e-01,
    1.01762e00,
    9.74365e-01,
    1.00060e00,
    9.82565e-01,
    9.70675e-01,
    9.78875e-01,
    9.79490e-01,
    9.86050e-01,
    9.76415e-01,
    9.61040e-01,
    9.58580e-01,
    9.94250e-01,
    1.01946e00,
    1.05719e00,
    1.06169e00,
    1.06477e00,
    1.11315e00,
    1.07440e00,
    1.09962e00,
    1.08691e00,
    1.11766e00,
    1.12012e00,
]
histograms_1e10 = [
    1.17650e00,
    1.11582e00,
    1.17527e00,
    1.15969e00,
    1.13037e00,
    1.08117e00,
    8.43370e-01,
    4.34600e-01,
    2.70395e-01,
    3.59570e-01,
    6.77320e-01,
    1.04919e00,
    1.05596e00,
    9.95685e-01,
    1.00102e00,
    9.75800e-01,
    9.95480e-01,
    9.76210e-01,
    9.94250e-01,
    1.01004e00,
    1.00450e00,
    1.03730e00,
    1.00573e00,
    9.83590e-01,
    9.87485e-01,
    9.74570e-01,
    9.43410e-01,
    9.72110e-01,
    9.52840e-01,
    9.95480e-01,
    9.98965e-01,
    1.03218e00,
    1.07933e00,
    1.10741e00,
    1.15764e00,
    1.15661e00,
    1.20848e00,
    1.22652e00,
    1.22447e00,
    1.25276e00,
    1.22098e00,
]

fig, ax1 = plt.subplots()
ax1.set_title("CB/CFCMC histograms 200K", fontsize=10)
ax1.set_xlabel(r"Coupling parameter $\lambda$ / -", fontsize=20)
ax1.set_ylabel("Frequency / -", fontsize=16)
# ax1.set_xscale("log")
ax1.errorbar(lambdas, histograms_1e2, color="purple", label="f = 1e2 Pa", marker="+")
ax1.errorbar(lambdas, histograms_1e4, color="red", label="f = 1e4 Pa", marker="s")
ax1.errorbar(lambdas, histograms_1e6, color="black", label="f = 1e6 Pa", marker="<")
ax1.errorbar(lambdas, histograms_1e8, color="lightblue", label="f = 1e8 Pa", marker="^")
ax1.errorbar(lambdas, histograms_1e10, color="orange", label="f = 1e10 Pa", marker="o")
ax1.legend(loc="upper right")
plt.ylim([0, 2.0])
plt.xlim([0.0, 1.0])
